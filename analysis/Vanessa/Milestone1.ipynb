# %%
import pandas as pd

# %%
game_shifts = pd.read_csv("/Users/vanessadunn/Documents/School/4thYear/Data301/game_shifts.csv")
game_shifts.head(50)
# Out:
#        game_id  player_id  period  shift_start  shift_end
# 0   2018020001    8466139       1            0       42.0
# 1   2018020001    8466139       1          207      247.0
# 2   2018020001    8466139       1          375      413.0
# 3   2018020001    8466139       1          556      574.0
# 4   2018020001    8466139       1          605      631.0
# 5   2018020001    8466139       1          662      703.0
# 6   2018020001    8466139       1          869      883.0
# 7   2018020001    8466139       1          941      968.0
# 8   2018020001    8466139       1         1146     1200.0
# 9   2018020001    8466139       2         1200     1219.0
# 10  2018020001    8466139       2         1356     1388.0
# 11  2018020001    8466139       2         1416     1459.0
# 12  2018020001    8466139       2         1566     1619.0
# 13  2018020001    8466139       2         1727     1773.0
# 14  2018020001    8466139       2         1929     2004.0
# ...
